# %% [markdown]
# # LlamaIndex

# %% [markdown]
# ### Within the framework of **llamaindex**, the main elements of **RAG** are represented by the following modules:
#
# 1. **Data Connectors:** These are modules responsible for loading and processing data. They allow you to load data, create nodes from them, and build an index.
#
# 2. **Retrievers:** These modules are responsible for searching the index. They enable searching the index and obtaining the most relevant nodes.
#
# 3. **Query Engines:** These modules are responsible for generating a response to a query. They use information obtained from retrievers to generate a response.

# %%
from llama_index import VectorStoreIndex, SimpleDirectoryReader # Data Connectors

# %%
import openai
import os
from dotenv import load_dotenv, find_dotenv
_=load_dotenv(find_dotenv()) # read loacl .env file

# %%
openai.api_key = os.getenv("OPENAI_API_KEY")

# %%
DATA = os.getenv('DATA')
documents = SimpleDirectoryReader(DATA).load_data()

# %%
documents
# Out:
# [Document(id_='03b36c9e-ebb4-450d-a295-12abfffad50b', embedding=None, metadata={'file_path': '/Users/gala/PycharmProjects/Scalian_Chat/ScalianChatBot/Data/www_scalian-spain_es_.txt', 'file_name': 'www_scalian-spain_es_.txt', 'file_type': 'text/plain', 'file_size': 7028, 'creation_date': '2024-02-06', 'last_modified_date': '2024-02-06', 'last_accessed_date': '2024-02-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='title:\nurl:\n\nDESCUBRE SCALIAN SPAIN\n\n\n - Descubre las nuevas perspectivas del negocio basadas en datos\n - Una nueva era de datos, procesamiento masivo de información e Inteligencia Artificial está marcando el futuro de los procesos empresariales, sociales, económicos y políticos. \u200b\n - Descubre nuestras especialidades\n\n - La vida se construye a base de experiencias\n - "Hay gente que prefiere tener una experiencia de vida... nosotros preferimos tener una vida de experiencias."\n\n - Con esta filosofía en mente estamos contribuyendo de forma significativa a la evolución y digitalización de los principales sectores de la economía.\n - Descubre nuestras experiencias\n\n - Puro Talento y Tenacidad\n - Decía pablo Picasso que “la inspiración existe, pero tiene que encontrarte trabajando” por ello no existe talento sin tenacidad e insistencia. \u200b\n\n - En Scalian te ayudaremos e inspiraremos para que puedas reforzar tus hard skills: conocimiento técnico puntero en áreas tecnológicas novedosas,  pero también tus soft skills: disciplina, resiliencia, tenacidad, pero sobre todo pasión por las cosas bien hechas…\u200b\n - Únete a nosotros\n\nUna compañía con propósito\n\n\nNuestro objetivo es crear una “comunidad de\xa0profesionales consciente”\xa0dentro de un espacio de desarrollo\xa0profesional que fomente los vínculos y sinergias\xa0entre todos sus\xa0miembros, así como la creatividad y la evolución tanto profesional como\xa0personal.Un entorno en el que la combinación de servicios\xa0proporcione un\xa0equilibrio perfecto entre orientación estratégica,\xa0capacidades técnicas para el desarrollo\xa0de soluciones digitales y el\xa0apoyo operativo que permitan ayudar a nuestros clientes a hacer evolucionar\xa0su negocio tanto desde la perspectiva de rendimiento operativo como\xa0de\xa0las\xa0sostenibilidad\xa0al tiempo que se contribuye a la mejora de la\xa0sociedad y del planeta.Como expertos en datos y soluciones tecnológicas nuestra misión es la\xa0de crear entornos\xa0digitales eficaces, diseñar arquitecturas de datos\xa0escalables, desarrollar servicios\xa0interoperables, integrar inteligencia\xa0artificial en los flujos de trabajo de toma de\xa0decisiones y\xa0automatización, al tiempo que proporcionamos una gestión ágil de\xa0los\xa0proyectos y un despliegue continuo de los servicios que garanticen\xa0unas operaciones\xa0más inteligentes y mejoren la cadena de valor de\xa0nuestros clientes.\n\n\nHacemos\xa0de\xa0SCALIAN\n\n\nun\xa0lugar\xa0al\xa0que\xa0desees\xa0pertenecer\xa0y\xa0en\xa0el\xa0que\xa0quieras\xa0permanecer\n\n\ncontribuyendo\xa0así\xa0a\xa0\xa0un\xa0bien\xa0común.\u200b\n\n\nEspecializados en aspectos clave de tu negocio\n\n\nOperations PerformanceReducimos los costes operativos garantizando la calidad de la producción.\n\n\nData & InsightsTransformamos los datos para entender mejor el negocio.\n\n\nDigital SolutionsDominio de las tecnologías y evolución de los sistemas legacy.\n\n\nStrategy &TransformationOfrecemos modelos negocio digitales potentes así como disrupción tecnológica.\n\n\nNUESTROS SERVICIOS\n\n\nEl Talento es la "piedra angular" de nuestra existencia.\n\n\nEl fomento de la excelencia técnica y el talento creativo de nuestros empleados es la clave de bóveda que sostiene la estructura de Scalian y nos permite diseñar soluciones imaginati ...
#  Document(id_='5d7fb09f-2866-4c2e-8c11-f84d21a3449a', embedding=None, metadata={'file_path': '/Users/gala/PycharmProjects/Scalian_Chat/ScalianChatBot/Data/www_scalian-spain_es_blog.txt', 'file_name': 'www_scalian-spain_es_blog.txt', 'file_type': 'text/plain', 'file_size': 4659, 'creation_date': '2024-02-06', 'last_modified_date': '2024-02-06', 'last_accessed_date': '2024-02-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nBlog\n\n\n - ”Todo lo que escuchamos es una opinión, no un hecho. Todo\xa0lo que vemos es una perspectiva, no es la verdad”\n - Marco AurelioAquí podrás encontrar nuestras opiniones y perspectivas sobre la actualidad de la Innovación, la Inteligencia Artificial, el Big Data, el Cloud, así como todo aquello relacionado con el desarrollo tecnológico y los casos de uso de negocio que están revolucionando el mundo.\n\n - 30/01/2024\n - |\n - Cloud, Inteligencia Artificial, Tecnología\n - Transformando la Industria 4.0 para un futuro más eficienteEn Scalian Spain somos una empresa especializada en servicios de Data & Insights y Digital Solutions que no sólo destaca\n - Seguir leyendo\n\n - 25/01/2024\n - |\n - Ciberseguridad, Inteligencia Artificial, Tecnología\n - Las 5 claves de la Gestión de Datos en 2024En la era digital, la gestión de datos sabemos que se posiciona como un componente esencial para el éxito empresarial.\n - Seguir leyendo\n\n - 02/01/2024\n - |\n - Inteligencia Artificial, Tecnología\n - Descubre las 10 tendencias tecnológicas que definirán el panorama en 2024El año 2024 se avecina con emocionantes avances tecnológicos que prometen cambiar la forma en que vivimos y trabajamos. En\n - Seguir leyendo\n\n - 26/12/2023\n - |\n - Inteligencia Artificial, Tecnología, Transformación Digital\n - La UE da un paso histórico hacia la Regulación Ética de la Inteligencia Artificial¿Hasta dónde estamos dispuestos con el uso de la IA? ¿Dónde se encuentra la delgada línea entre la innovación y\n - Seguir leyendo\n\n - 12/12/2023\n - |\n - Inteligencia Artificial, Tecnología, Transformación Digital\n - Todo lo que pasó durante el AWS re:Invent 2023Desde el 27 de noviembre hasta el 1 de diciembre de 2023, tuve el privilegio de asistir a uno de\n - Seguir leyendo\n\n - 04/12/2023\n - |\n - Inteligencia Artificial, Tecnología, Transformación Digital\n - ¡Visitamos el Databricks Data+AI World Tour Madrid!¡Hola Scalians!\xa0 El pasado martes 28 de Noviembre tuve la oportunidad de asistir en al Data+AI World Tour Madrid, evento\n - Seguir leyendo\n\n - 30/11/2023\n - |\n - Inteligencia Artificial, Tecnología\n - La Revolución de la Inteligencia Artificial: El poder transformador de los Modelos de Lenguaje a Gran Escala (LLM)En las últimas décadas, la Inteligencia Artificial (IA) ha trazado una trayectoria de crecimiento sin precedentes, ha transformado nuestra relación\n - Seguir leyendo\n\n - 23/11/2023\n - |\n - Ciberseguridad, Inteligencia Artificial, Tecnología\n - Conoce las diferencias claves entre Data Lake, Data Warehouse y Data CatalogEn el contexto actual, las organizaciones se enfrentan cada día a un gran desafío: gestionar volúmenes crecientes de datos. Sin\n - Seguir leyendo\n\n - 14/11/2023\n - |\n - Inteligencia Artificial, Tecnología, Transformación Digital\n - Las prácticas que han revolucionado la industria AeronáuticaLa industria aeronáutica destaca como una de\xa0las más exigentes en términos de seguridad, precisión y calidad.\xa0La implementación de la metodología\xa0APQP\xa0(Advanced\n - Seguir leyendo\n\n - 26/10/2023\n - |\n - Formación, Inteligencia Artificial, Talento\n - ¡Acelerando hacia el conocimiento con 12 + 1 Programas Propios!En Scalian Spain, estamos entusiasmados de anunciar nuestra oferta educativa de los próximos meses: ¡12 + 1 Program ...
#  Document(id_='7eae410f-efac-4dd6-8a57-dce9278e3f00', embedding=None, metadata={'file_path': '/Users/gala/PycharmProjects/Scalian_Chat/ScalianChatBot/Data/www_scalian-spain_es_contacto.txt', 'file_name': 'www_scalian-spain_es_contacto.txt', 'file_type': 'text/plain', 'file_size': 356, 'creation_date': '2024-02-06', 'last_modified_date': '2024-02-06', 'last_accessed_date': '2024-02-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nContacto\n\n\nContacta con nosotros\n\n\nMadrid\n\n\nAvda. General Perón 36, 2ª Planta. 28020\n\n\n+34 91 538 85 68\n\n\ninfo.spain@scalian.com\n\n\nMálaga\n\n\nC/ San José 2, Planta 1. 29015\n\n\nAlicante\n\n\nAvda. Doctor Gadea, 4. 03001\n\n\nBarcelona\n\n\nAv. Diagonal 571, 2ª Planta. 08029\n\n\nHe leído, entiendo y acepto la Política de Privacidad\n\n\n*Campos obligatorios\n\n\nΔ\n\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='2969b878-3ca4-4929-b507-c3484ea9012b', embedding=None, metadata={'file_path': '/Users/gala/PycharmProjects/Scalian_Chat/ScalianChatBot/Data/www_scalian-spain_es_especializacion.txt', 'file_name': 'www_scalian-spain_es_especializacion.txt', 'file_type': 'text/plain', 'file_size': 3431, 'creation_date': '2024-02-06', 'last_modified_date': '2024-02-06', 'last_accessed_date': '2024-02-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nNuestra Especialización\n\n\nOfrecemos nuevas perspectivas sobre tu negocio gracias al análisis de todos tus datos tanto internos como externos. Ponemos a tu servicio todo el potencial de la IA al servicio de los humanos, para tomar decisiones conscientes que estén alineadas con la misión y valores de la empresas y por supuesto al servicio de las personas.\n\n\n - ¿En qué somos\n - especialistas?\n\n - Más de 20 años y los clientes que han sido pioneros en la adopción de las nuevas tecnologías\xa0avalan nuestra especialización y nuestra experiencia en digitalización de procesos de negocio.\xa0\xa0Desde Scalian Spain\xa0 hemos acompañado a múltiples compañías en el fascinante viaje hacia la evolución digital de su organización. Somos especialistas en estrategia & innovación, con capacidades metodológicas y digitales\xa0 así como en soporte operativo, todo ello orientado a mejorar el rendimiento de sus negocios.\n - En Scalian Spain nos diferenciamos aportando un valor incremental\xa0 a los procesos de automatización y de decisión así como a la eficiencia del negocio:\n\nUna buena comprensión de la estrategia y de las funciones de negocio.\n\n\nUso de tecnologías basadas en inteligencia del dato (IA).\n\n\nBuen gobierno del dato en todo su ciclo de vida.\n\n\nUna gestión ágil.\n\n\nServicios de soporte a los procesos de negocio y de mantenimiento.\n\n\nNuestra combinación de servicios nos\xa0permite desarrollar nuevos negocios y desplegar operaciones más inteligentes.\n\n\nDigital Solutions\n\n\nDigital Solutions\n\n\nDominio de las tecnologías y evolución de los sistemas legacy.\n\n\nSaber más\n\n\nCiberseguridad\n\n\nCiberseguridad\n\n\nNuestra visión para proteger tu negocio.\n\n\nSaber más\n\n\nData & Insights\n\n\nData & Insights\n\n\nTransformamos los datos para entender mejor el negocio.\n\n\nSaber más\n\n\nOperations Performance\n\n\nOperations Performance\n\n\nReducimos los costes operativos garantizando la calidad de la producción.\n\n\nSaber más\n\n\nStrategy & Transformation\n\n\nStrategy & Transformation\n\n\nOfrecemos modelos negocio digitales potentes así como disrupción tecnológica.\n\n\nSaber más\n\n\nAyudamos a cada empresa en su proceso de Transformación Digital, entendiendo las verdaderas necesidades de su negocio.\n\n\nCada empresa tiene sus propias caracteristicas por eso proporcionamos a cada una la metodología, las herramientas y las soluciones que le ayuden a conseguir de forma ágil la necesaria disrupción y transformación en sus procesos, aportando los conocimientos y las capacidades para generar una impacto positivo en la organización acelerado por la tecnología.\n\n\n4 etapas para garantizar el éxito del proyecto\n\n\n0%\n\n\nAsistencia Técnica\n\n\n0%\n\n\nProyectos cerrados\n\n\n0%\n\n\nServicios gestionados\n\n\n - En Scalian Spain atendemos tanto  proyectos nacionales como internacionales\n - con  equipos estables  en constante  crecimiento profesional para ser siempre  punteros en nuestras áreas de expertise .\n\nEnfoque Global.\n\n\nComo empresa internacional aportamos soluciones adaptadas al mercado nacional de cada país respondiendo a sus necesidades sin perder de vista los objetivos del grupo y de los usuarios.\n\n\nPonemos a tu disposición a los más de 400 expertos de Scalian Spain con un profundo conocimiento l ...
#  Document(id_='f020f05e-3715-48d6-9124-0cf1f15477c4', embedding=None, metadata={'file_path': '/Users/gala/PycharmProjects/Scalian_Chat/ScalianChatBot/Data/www_scalian-spain_es_especializacion_ciberseguridad.txt', 'file_name': 'www_scalian-spain_es_especializacion_ciberseguridad.txt', 'file_type': 'text/plain', 'file_size': 15434, 'creation_date': '2024-02-06', 'last_modified_date': '2024-02-06', 'last_accessed_date': '2024-02-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nCiberseguridad\n\n\nLos ciberdelincuentes nunca duermen, por eso  ahora más que nunca es momento de asegurar el acceso a tus datos y aplicaciones con soluciones disruptivas.\n\n\nNuestra visión para proteger tu negocio.\n\n\nEn Scalian somos conscientes de que los usuarios, las redes, los dispositivos, las aplicaciones y los datos cada vez están más expuestos y comprometidos a medida que las hacemos evolucionar hacia entornos distribuidos como son la nube. Por otro lado, los sistemas modernos interactúan y se integran con otros sistemas de clientes o proveedores y cada vez más usuarios tanto internos como externos a la empresa tienen acceso a los servicios críticos dentro de una cadena de gestión de los procesos de las empresas conectadas.Por ello, hemos diseñado un modelo de ciberseguridad que pone el foco en el usuario y tiene dos ejes fundamentales de actuación:\n\n\nPor un lado, un modelo de confianza cero (Zero Trust) que se centra la gestión de la identidad con la autenticación y autorización de los usuarios para un uso más seguro de dispositivos, aplicaciones y datos.\n\n\nY por otro un modelo de concienciación (Safe Awareness) ciber que ayuda a evitar riesgos potenciales a través de la formación y concienciación de los usuarios ya que estos son el eslabón más débil de la cadena.\n\n\nEstrategia de Zero Trust\n\n\nTras la crisis del COVID-19, el perímetro de ciberseguridad tradicional focalizado en la securización de las redes corporativas ha cambiado radicalmente. Con el aumento de la superficie de ataque debido al teletrabajo en la que un gran número de trabajadores han acabado trabajando en sus casas con sus portátiles personales sin securizar y conectados a un router sin configurar.O con la creciente adopción de modelos híbridos basados en la nube a partir de migraciones de sistemas legacy.O también con los llamados dispositivos IoT conectados a internet\xa0ha provocado que\xa0ese perímetro que teníamos controlado desaparezca.Por este motivo, nuestra estrategia de Zero Trust ha cobrado más fuerza que nunca al tratar a todos los usuarios, dispositivos, servicios, …\xa0 como si fueran ciberdelincuentes mientras no\xa0 estén autenticados y cumplan con sus políticas de acceso.\n\n\nA continuación, indicamos algunos de los principios básicos de Zero trust:\n\n\nLa red siempre es un medio hostil.\n\n\nLas amenazas pueden venir tanto del exterior como del interior.\n\n\nLas redes internas no son siempre seguras.\n\n\nTodos los usuarios, dispositivos... siempre se deben autenticar y autorizar.\n\n\nDebemos de monitorizar todo el tráfico de la red.\n\n\n¿Cómo lo hacemos?\n\n\n1. Autentificación\n\n\nDescripciónServiciosCasos de usoBeneficios\n\n\n - Gracias a la tecnología de localización única de Ironchip, mediante localización segura por ondas de radiofrecuencias que aporta un nuevo enfoque de defensa ante los problemas de ciberseguridad actuales, tanto de manera activa o pasiva podemos garantizar la Autenticación de la Identidad.\n - Location technology: Gracias a la IA que analiza las ondas de una localización específica, creando una huella asociada a ese lugar. Integramos esta ubicación para acceder a tus IT/IoT como una capa de seguridad extra para validar el acceso seguro del usuario, con un dispositivo asoc ...
#  Document(id_='20fdcdeb-8f92-4d48-91d5-f7a5638db478', embedding=None, metadata={'file_path': '/Users/gala/PycharmProjects/Scalian_Chat/ScalianChatBot/Data/www_scalian-spain_es_especializacion_data-insights.txt', 'file_name': 'www_scalian-spain_es_especializacion_data-insights.txt', 'file_type': 'text/plain', 'file_size': 19072, 'creation_date': '2024-02-06', 'last_modified_date': '2024-02-06', 'last_accessed_date': '2024-02-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nData & Insights\n\n\nDescubre las nueva perspectiva que pueden aportar la analítica avanzada de tus datos y la computación en la nube al negocio y a tus operaciones.\n\n\n - Hacia un nuevo orden\n - de las cosas guiado por datos.\n\nSCALIAN SPAIN se caracteriza por su excelente desempeño en proyectos de alta complejidad técnica y funcional aplicando modelos de eficiencia y de gestión ágil que han sido ampliamente probados en el diseño, desarrollo, pruebas, despliegue y operaciones datos, modelos de machine learning así como el uso de las capacidades de almacenamiento y computación distribuida en la Nube.\n\n\nImpulsamos la creación de valor y la transformación de tu empresa a partir del análisis de todos los datos disponibles tanto internos como externos.\n\n\nNuestro servicio DATA & INSIGHTS es un concepto holístico que combina el uso de la nube, la ingeniería del dato, la ciencia de datos y la inteligencia artificial para proporcionar soluciones basadas en infraestructuras y arquitecturas de datos flexibles y seguras, que den soporte a los casos de uso de analítica avanzada que ayuden a la empresa a consolidar una visión completa e integrada de sus datos, sus patrones de comportamiento y que sirvan para alimentar los procesos de toma de decisiones y de automatización.\n\n\nTransformar es "cambiar la forma de hacer las cosas" pero sin renunciar a tu esencia ni alterar aquello que te hace único.\n\n\nDurante más de 20 años hemos acompañado a multitud de empresas en su camino hacia la transformación digital de sus negocios y lo hemos hecho desde una perspectiva completa que cubre cuatro objetivos transformacionales básicos: cultura y organización, procesos, así como en el modelo de negocio y/o de dominio.\n\n\nMÁS SOBRE ESTRATEGIA Y TRANSFORMACIÓN\n\n\nLa transformación digital requiere previamente una transformación de las personas, de su mentalidad y sus habilidades así como cambios en la cultura y capacidades organizativas de las empresas para adaptarlas a la realidad que impone la digitalización: ciclos mas cortos de ensayo y error, mayor flexibilidad en el trabajo, hiper-especialización, agilidad y descentralización de la toma de decisiones y mayor dependencia de otros proveedores tecnológicos.\xa0La transformación de los procesos de negocio se centra en áreas específicas de las empresas (contratación, contabilidad, facturación, logística, …) y pude generar un enorme valor en un corto plazo\xa0 reduciendo los costes, mejorando la calidad de los productos y servicios, aumentando el rendimiento de las operaciones, etc. En este contexto, transformar los procesos implica rediseñar los aspectos clave desde el almacenamiento los datos a su procesamiento en la nube, pasando por la creación las API y el aprendizaje automático, la visualización de los resultados, la experiencia de usuario, etc. Zara transformó sus procesos de negocio mediante reimaginando la forma de diseñar, fabricar y entregar los productos en las tiendas (entre otros) lo que le dio una clara ventaja competitiva.Las transformaciones del modelo de negocio se centra en reinventar la forma en la que se entrega el valor a los clientes (productos o servicios) en un sector específico. Como ejemplo de este tipo tenemos empresas como Spotify y Netflix, que cambia ...
#  Document(id_='6ffbee0e-3b5e-4897-9fd1-02d886e71e09', embedding=None, metadata={'file_path': '/Users/gala/PycharmProjects/Scalian_Chat/ScalianChatBot/Data/www_scalian-spain_es_especializacion_digital-solutions.txt', 'file_name': 'www_scalian-spain_es_especializacion_digital-solutions.txt', 'file_type': 'text/plain', 'file_size': 5034, 'creation_date': '2024-02-06', 'last_modified_date': '2024-02-06', 'last_accessed_date': '2024-02-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nDigital Solutions\n\n\nLa innovación digital se ha convertido en la frontera de la mejora de los servicios. Porque cada actividad es específica, tus herramientas informáticas también deben serlo.\n\n\nConocer al cliente, proteger el negocio  son la clave para crecer en el mercado ofreciendo garantías de futuro.\n\n\nThink big – Proyectos ambiciososSi piensas en grande te ayudaremos a racionalizar los proyectos y volverlo tangible. La tecnología permite hacer cosas grandes y espera de nosotros cosas grandes por esos nuestros equipos están capacitados para acompañarte en el viaje con temas de ciberseguridad, Análisis por actividad, arquitectura de sistemas y auditoría (UX, técnica, funcional, rendimiento)\n\n\nPlay Video\n\n\nStart small – Pequeños pasos con impactoIr poco a poco permite controlar mejor los proyectos y facilitan el aprendizaje, dejan ajustar, corregir y medir hasta que funcionan.\xa0 Todo ello, estableciendo una base y generando confianza. Además como son pequeños pasos permiten hacer más con costes de tiempo y recursos ajustados.\n\n\nScale fast – Monetizar y expandirCon la estrategia definida podemos pensar en duplicar, ampliarnos e impulsar el negocio. Integrando aspectos tecnológicos, humanos y de procesos en la organización hacemos crecer el ecosistema del IoT de una forma rápida y eficaz. Además gracias a los pequeños pasos que hemos dado podemos monetizar la innovación, además de crear capacidades sólidas, impulso y confianza de una forma segura.\n\n\nEn Scalian Spain creemos que nuestro mayor impacto no viene entregando una pantalla para el interfaz de usuario por muy deslumbrante que sea. Nuestros expertos trabajan para  acordar los grandes pensamientos, implementar las necesidades de los usuario y luego, con la confianza construida y la fe en la tecnología, escalar una solución para ofrecer continuamente el retorno de la inversión digital a largo plazo de nuestros clientes y partners.\n\n\nImpulsamos la tecnología como herramienta para aumentar la productividad y competitividad de nuestros clientes a través de nuestros servicios:\n\n\nProcedimientos de licitación de proyectos digitales Con este servicio ayudamos a nuestros clientes a establecer un alcance acotado y  baremo de precios preciso para un determinado proyecto (Request for Quotation); definir y valorar las cualidades que debe cumplir una empresa para proporcionar un servicio o producto determinado (Request for Qualification); ayudar a definir las  RFI (Request for Information) así como los requisitos que deben cumplir proveedores; y por último la definición de pliegos en procesos de RFP (Request for Proposals) y la evaluación de la capacidad técnica, financiera y recursos que va a emplear, tanto materiales como humanos.\u200b\n\n\nDescubrimiento de solucionesNuestro equipo de asesores guiará desde el primer momento a tus equipos, para analizar y valorar las distintas opciones tecnológicas disponibles, descubrir requerimientos específicos, analizar los riesgos, estimar el presupuesto, el tiempo, la planificación del proyecto, y determinar tanto los recursos técnicos como humanos necesarios para abordar con éxito el proyecto.\u200b\n\n\nDesarrollo de soluciones a medida\u200bNuestros equipos tienen la experiencia y el talento par ...
#  Document(id_='33d0898b-9969-4108-a88b-d165be8e143a', embedding=None, metadata={'file_path': '/Users/gala/PycharmProjects/Scalian_Chat/ScalianChatBot/Data/www_scalian-spain_es_especializacion_operations-performance.txt', 'file_name': 'www_scalian-spain_es_especializacion_operations-performance.txt', 'file_type': 'text/plain', 'file_size': 4125, 'creation_date': '2024-02-06', 'last_modified_date': '2024-02-06', 'last_accessed_date': '2024-02-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nOperations Performance\n\n\nCombinamos la capacidad de digitalización de procesos y transformación digital junto con nuestra aptitud de gestión del rendimiento de las operaciones para asegurar una transición segura a nuevos paradigmas de gestión de las operaciones.\n\n\nImpulsando el negocio.\n\n\nEn Scalian Spain somos expertos en ayudar a las empresas a establecer sinergias entre sus distintas unidades productivas y departamentos dotándolos de las herramienta y los servicios que que les permitan incrementar de forma considerable su rendimiento y su capacidad operativa para producir conjuntamente de forma que se consigan los objetivos empresariales que se propongan al tiempo que se mejora la capacidad de respuesta, el rendimiento, la calidad, el coste y la eficiencia de sus sistemas de producción o servicios.\n\n\nPlay Video\n\n\nOperacionesmás inteligente.\n\n\nNuestra división de Operations Performance cuenta con expertos que le ayudan a optimizar sus procesos, mejorar la inteligencia de sus operaciones, así como la previsión, planificación que ayuden a establecer de políticas y programas de producción.Todo ello soportado con las tecnologías de última generación y el apoyo de nuestra división de Data & Insights que ayudan en el desarrollo de sistemas de recopilación de datos y los procesos digitales y algoritmos que le permiten visualizar y analizar en tiempo real lo que está ocurriendo en su cadena de suministro y producción.Nuestra propuesta incluye además expertos en sistemas de gestión del rendimiento de sus activos que se centran en mejorar la fiabilidad y la disponibilidad de sus activos físicos e instalaciones al tiempo que minimizan el riesgo y los costes operativos.\n\n\nHacia empresainteligente.\n\n\nConectividad y digitalización de las operaciones y procesos de fabricaciónLas nuevas operaciones se basan en servicios de conectividad y gestión de dispositivos de Edge computing, IOT, despliegue de aplicaciones en la nube, seguridad, integración, servicios cognitivos, etc. Operaciones basadas en WebServices API\n\n\nLa innovación en la gestión de operaciones y su digitalización debe ser capaz de ofrecer soluciones que ayuden a reaccionar con agilidad ante los cambios en las dinámicas de los mercados así como en\xa0 las expectativas de los clientes, llegando a todos los rincones de la organización pero muy especialmente, al diseño, la fabricación y la cadena de suministro, de forma que se puedan supervisar y ajustar los procesos de forma rápida y automática, y evaluar rápidamente escenarios alternativos cuando se produzcan los inevitables fallos.Innovar en este contexto no es sólo implantar tecnologías disruptivas para mejorar las operaciones sino que también y muy especialmente significa implicar a las personas que tienen que interactuar con la tecnología, haciéndolas participes de los cambios y transformar los procesos y sistemas que manejen los datos y la información con fluidez.\n\n\nUna oferta de servicios adaptada a las necesidades de la empresa Inteligente:\n\n\nGestión de proyectos con equipos volcados en el negocioDirigimos de forma eficiente cada proyectos planificación detalladamente la ejecución y el control hasta garantizar su éxito.\n\n\n - Gestión de compras y proveedores y opti ...
#  Document(id_='3a423d3a-7167-4065-9c88-4c0f7f106448', embedding=None, metadata={'file_path': '/Users/gala/PycharmProjects/Scalian_Chat/ScalianChatBot/Data/www_scalian-spain_es_especializacion_strategy-and-transformation.txt', 'file_name': 'www_scalian-spain_es_especializacion_strategy-and-transformation.txt', 'file_type': 'text/plain', 'file_size': 6176, 'creation_date': '2024-02-06', 'last_modified_date': '2024-02-06', 'last_accessed_date': '2024-02-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nStrategy & Transformation\n\n\nTe acompañamos en crecimiento de tu negocio con soluciones innovadoras que responden a la demanda del mercado y de tus clientes y te ayudamos a anticiparte sus necesidades.\n\n\nTransformar el negocio es estar preparados para cualquier situación futura.\n\n\nDesde Scalian Spain hemos entendido que para que haya una verdadera Transformación del Negocio no vale con una simple transformación digital.\xa0 Primero debemos: estar atentos a qué productos y servicios demanda el mercado (clientes potenciales), conocer las expectativas de nuestros propios clientes, tener establecido de forma anticipada un modelo de negocio ágil y dinámico capaz de adaptarse rápidamente ante posibles cambios, y contar con procesos de negocio capaces de cambiar el modelo de negocio en el momento justo y no después. Por eso, rodeados de un equipo de consultores altamente preparados proponemos soluciones que permitan a nuestros clientes ser eficientes hoy, pero preparados para cualquier situación futura porque habremos podido anticiparnos al mercado y a nuestros competidores.\n\n\nPlay Video\n\n\nMediante la integración de factores humanos y tecnológicos, nuestros equipos se encargan de la optimización de los proyectos y de los problemas de rendimiento organizativo, así como de los retos de transformación digital para los líderes de la industria y el sector de los servicios. Nos basamos en nuestra capacidad para operar en entornos complejos y crear soluciones a medida.\n\n\nDiseñamos, optimizamos e implementamos los planes estratégicos desde todas tus iniciativas.\n\n\nIniciativas financieras, de recursos humanos, clientes, innovación y procesos, basadas en 4 factores clave:\n\n\nValor Añadido Estratégico\n\n\nAyudamos a los usuarios a comprender las oportunidades empresariales que se pueden abordar con la tecnología emergente y cómo aprovecharla.\n\n\nPerformance Management.\n\n\nConocimiento del Negocio\n\n\n - Mejoramos la experiencia del cliente y del usuario.\n - Ayudamos a canalizar y controlar los costes de cada actividad.\n - Promovemos una cultura innovadora en toda la empresa basada en la innovación.\n - Fomentamos el talento.\n\nCapacidad de Ejecución\n\n\n - Modelos de colaboración eficientes y sostenibles.\n - Expertise funcional y tecnológico.\n - Centros de servicios con compromiso.\n\nCapacidades en Tecnología del Dato\u200b\n\n\n - Ayudamos a los líderes empresariales a identificar el valor y el ROI de sus datos.\n - Familiarizamos los líderes empresariales no técnicos con Big Data, IA y Cloud.\n\nNuestras Soluciones end to end responden a las funcionalidades críticas de tu negocio.\n\n\nEnterprise Performance\n\n\nAnalizamos la información de la empresa para poder generar informes con el objetivo de mejorar el rendimiento de la compañía guiándoles hacia el futuro.\n\n\nStrategic Planning\n\n\nParticipamos en la elaboracióm de la planificación estrategica para definir la visión de futuro y las metas de la compañia desde un punto de vista global con una solida y demostrable experiencia.\n\n\nCustomer Interaction\n\n\nAyudamos a consolidad la relación con el cliente dándole su lugar en la estrategia de la empresa y buscando soluciones para mejorar su experiencia.\n\n\nBusiness  ...
#  Document(id_='9749174e-669e-4059-b608-2cc1c0f84ddf', embedding=None, metadata={'file_path': '/Users/gala/PycharmProjects/Scalian_Chat/ScalianChatBot/Data/www_scalian-spain_es_experiencias-de-negocio.txt', 'file_name': 'www_scalian-spain_es_experiencias-de-negocio.txt', 'file_type': 'text/plain', 'file_size': 3286, 'creation_date': '2024-02-06', 'last_modified_date': '2024-02-06', 'last_accessed_date': '2024-02-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nExperiencias de Negocio\n\n\nNuestra variada cartera de clientes demuestra nuestra capacidad para trabajar en todos los sectores de "alta complejidad", sujetos a grandes retos tecnológicos, organizativos e industriales.\n\n\n - Estamos presentes en\n - la mayoría de sectores\n\nNuestro objetivo es conocer el negocio de nuestros clientes, y desde esa perspectiva, ofrecerles soluciones creativas desarrolladas por profesionales decididos y talentosos, expertos en brindar la tecnología adecuada en cada caso:\n\n\nSea cual sea el sector ofrecemos soluciones End-to-End\n\n\nProporcionar\xa0soluciones multidisciplinares sólidas e innovadoras\xa0a los requisitos industriales mediante el\xa0desarrollo, la adquisición y el despliegue\xa0de los conocimientos así como con las metodologías adecuadas.\n\n\n - Nuestros expertos aprovechan las tecnologías para\n - abordar los objetivos de su organización y ejecutar estrategias tácticas que hagan crecer y preservar la salud de su negocio. Escuchamos sus necesidades y desarrollamos las soluciones adecuadas.\n\nBanca & Servicios Financieros\n\n\nLos bancos tradicionales y las instituciones financieras están siendo desafiadas por el aumento de nuevos competidores como fintech, empresas tecnológicas y telcos que están proporcionando cuentas corrientes y de ahorro, tarjetas de crédito, préstamos, auto servicios y productos financieros.\n\n\nSaber más\n\n\nSalud\n\n\nCamino hacia una medicina P4. La asistencia sanitaria está evolucionando de una atención reactiva a la enfermedad a una atención predictiva, preventiva, personalizada y participativa.\n\n\nSaber más\n\n\nAutomoción\n\n\nEnfocado desde hace años en el sector. Nuestro expertise abarca diferentes campos empleando visión artificial,Análisis de datos para mejorar los automóviles a través de mantenimiento predictivo, sistemas embebidos, mantenimiento y evolución de arquitecturas y IT.\n\n\nSaber más\n\n\nEnergía\n\n\nDetección del fraude eléctrico mediante aprendizaje automático. Mediante el aprendizaje automático no supervisado conseguimos realizar el análisis para detectar el fraude a partir de datos de medición, datos de facturación y datos de contexto de cada abonado.\n\n\nSaber más\n\n\nTelco\n\n\nBuscar la eficiencia a través de un sistema de cálculo de Estadísticas de Seguro Multirriesgo (ESM) y el aumento de datos para seguros multirriesgo.\n\n\nSaber más\n\n\nIndustria\n\n\nSomos expertos en proyectos del sector Industrial con alto contenido tecnológico especializados en data-driven strategy, mantenimiento predictivo y detección de anomalías, IIoT, ofreciendo proyectos 360 optimizando recursos, infraestructuras y costes.\n\n\nSaber más\n\n\nRailway\n\n\nDesarrollamos proyectos que tiene como objetivo final lograr una mayor eficiencia en los procesos de mantenimiento y reparación de los trenes mediante la digitalización de datos y procesos.\n\n\nSaber más\n\n\nAerospace\n\n\nAportamos soluciones a la industria aeroespacial gestionando proyectos de transformación digital, realizando analíticas avanzadas en la cadena de suministros y servicios de ingeniería gracias a nuestros equipos altamente cualificados.\n\n\nSaber más\n\n\n - +\n - 0\n - sedes propias\n\nrepartidas por 10 países\n\n\n - +\n - 0\n - expertos\n\nofertas y productos end to  ...
#  Document(id_='a781310c-3e6f-4560-b24d-09319d039550', embedding=None, metadata={'file_path': '/Users/gala/PycharmProjects/Scalian_Chat/ScalianChatBot/Data/www_scalian-spain_es_experiencias-de-negocio_aeroespacial.txt', 'file_name': 'www_scalian-spain_es_experiencias-de-negocio_aeroespacial.txt', 'file_type': 'text/plain', 'file_size': 1750, 'creation_date': '2024-02-06', 'last_modified_date': '2024-02-06', 'last_accessed_date': '2024-02-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nAeroespacial\n\n\nDesde hace más de veinte años, formamos parte de la innovación en el sector aeroespacial optimizando procesos, buscando soluciones basadas en sistemas fiables, duraderos y competitivos.\n\n\nCalidad de proveedores y metodología APQP\n\n\nSomos pioneros en la implementación de la metodología APQP en el sector aeronáutico desde el 2013, y ayudamos a nuestros clientes a que sus proveedores adquieran los principales instrumentos.Además, asistimos en proyectos de transferencias de tecnología entre\xa0proveedores o plantas, introducción de nuevos productos (NPI) o\xa0grandes modificaciones mediante la gestión de hitos, gestión de\xa0la calidad y análisis de riesgos.\n\n\nAnalítica avanzada  aplicada a la cadena de suministro\n\n\nAyudamos a nuestros clientes a seleccionar qué problemáticas de la cadena de suministro\xa0 pueden resolverse con el análisis de datos y la aplicación de modelos predictivos (rendimiento de proveedores, identificación de riesgos de stock), así como en el descubrimiento del dato y posible explotación.\n\n\nGestión de proyecto   de transformación digital.\n\n\nAsistimos a la gestión de proyecto e implementación de PMO acompañando iniciativas de digitalización de las operaciones y evolución de las aplicaciones, como el desarrollo de plataformas colaborativas de desarrollo de producto (programa FCAS).\n\n\nSoporte técnico-funcional  de infraestructura.\n\n\nGracias a nuestros años de experiencia, nuestros equipos realizan el mantenimiento y evolución de la infraestructura y aplicaciones de ingeniería:\n\n\nGestión de requisitos (e.g. DOORS),\n\n\nDesarrollo de software\n\n\nIVVQ\n\n\nDocumentación\n\n\nEtc\n\n\nMediante el análisis y resolución de incidencias y el desarrollo de nuevas funcionalidades\n\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='ff843458-3e20-4d2d-9c9c-b42411846a90', embedding=None, metadata={'file_path': '/Users/gala/PycharmProjects/Scalian_Chat/ScalianChatBot/Data/www_scalian-spain_es_experiencias-de-negocio_automocion.txt', 'file_name': 'www_scalian-spain_es_experiencias-de-negocio_automocion.txt', 'file_type': 'text/plain', 'file_size': 2907, 'creation_date': '2024-02-06', 'last_modified_date': '2024-02-06', 'last_accessed_date': '2024-02-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nAutomoción\n\n\nTrabajamos en volver los procesos más eficientes e innovar en el diseño de productos y servicios mediante el uso de nuevas tecnologías.\n\n\n - El sector de automoción está experimentando una transformación sin precedentes, tanto por elementos de innovación (nuevas fuentes de energía, introducción de sistemas de ayuda a la conducción, etc.) como por la necesidad de ganar eficiencia en las operaciones en un sector cada vez más competitivo.\n - Scalian es un partner estratégico para los principales fabricantes por su gran experiencia en nuevas tecnologías, en la gestión de proyectos complejos y en la eficiencia de las operaciones.\n\nVisión ArtificialDesarrollamos modelos de Machine Learning y Deep Learning para la ayuda a la conducción, como la detección obstáculos en la vía, reconocimiento de señales o la detección de fatiga, así como modelos para la mejora de la fabricación, como la detección de piezas defectuosas.\n\n\nMantenimiento PredictivoUsamos los datos que se recolectan de los distintos sensores y dispositivos a bordo de los vehículos y diseñamos modelos de análisis predictivos.\n\n\nAnálisis de datos y telemetríaImplementamos plataformas para la recogida y procesamiento de datos de sensores en tiempo real. Además, realizamos análisis de los datos recogidos para detección de anomalías, análisis de causa raíz, sistemas de alertas, etc.\n\n\nSistemas EmbebidosTrabajamos con los principales fabricantes de automóviles para desarrollar software embebido utilizando lenguaje C++ (GNU STL) sobre Linux, siguiendo el ciclo de desarrollo de software V-cycle con conocimientos específicos de las directrices de desarrollo C++ de MISRA (The Motor Industry Software Reliability Association).\n\n\nMantenimiento y evolución de arquitecturas ITAsistimos en el diseño, desarrollo, despliegue y mantenimiento de soluciones IT en el entorno de cadena de suministro, manufactura de vehículos y post-venta: clarificación de requisitos de negocio, coordinación de proyecto, validación y Go-Live. Realizamos el análisis técnico-funcional de incidencias derivadas de aplicaciones en esta área de negocio.\n\n\nOptimiza tus servicios,  anticípate a las demandas de los clientes.\n\n\nDesde Scalian Spain , nos anticipamos a la demanda permitiéndole estar preparado y ofrecer servicios de vanguardia para atender a la demanda de los clientes con servicios concretos.odificación masiva y automática mediante procesos batch. Se integra con agrupadores de 3M (AP y APR) para agrupación de la casuística clínica.Se integra con los principales sistemas HIS/HCE mediante HL7 recibiendo el alta de episodios (datos de cabecera e informes) y enviando mediante HL7 el resultado de la codificación en formato RAE-CMBD.Adicionalmente puede generando un RAE-CMBD que se puede exportar directamente a las principales herramientas analíticas del CMBD del mercado.\n\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='3e4f1aa8-91b0-42d9-9724-bdd339a53bd6', embedding=None, metadata={'file_path': '/Users/gala/PycharmProjects/Scalian_Chat/ScalianChatBot/Data/www_scalian-spain_es_experiencias-de-negocio_banca-y-servicios-financieros.txt', 'file_name': 'www_scalian-spain_es_experiencias-de-negocio_banca-y-servicios-financieros.txt', 'file_type': 'text/plain', 'file_size': 6861, 'creation_date': '2024-02-06', 'last_modified_date': '2024-02-06', 'last_accessed_date': '2024-02-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nBanca y Finanzas\n\n\nTransformamos el negocio para hacerlo más eficiente en términos de rentabilidad.\n\n\nScalian Spain, impulsor tecnológico  de  la banca de hoy.\n\n\nDesde Scalian Spain ayudamos a las organizaciones bancarias y financiera a\xa0mejorar su\xa0eficiencia y su rendimiento en las\xa0 operaciones que requieren\xa0afrontar cambios tanto culturales como operativos\xa0de back office y nos implicamos en los\xa0 procesos de\xa0transformación digital\xa0para que sean capaces de\xa0escalar al\xa0tiempo que\xa0aumenta la tasa de crecimiento online y las expectativas de los clientes.\n\n\nSobrevivir en un entorno cada vez más competitivo.\n\n\nPara sobrevivir en este entorno trabajamos con nuestros clientes en crear sistemas escalables mediante plataformas big data en la nube que apoyan un ritmo de crecimiento más rápido por medio de nuevas tecnologías al tiempo que se automatizan gran parte de los\xa0 procesos y operaciones haciéndolas eficientes mediante modelos de aprendizaje automático.\n\n\nExperiencia de más de 20 años  en regulación bancaria, análisis de riesgos y blanqueo de capitales\n\n\nOfrecemos una experiencia única en España de más de 20 años en el análisis, medición de riesgos y blanqueo de capitales: desde la gestión de calidad de series históricas y procesos de simulación,\xa0 a complejos modelos de valoración, generación de métricas VaR, griegas, vectores de P&L, agregación de carteras, escenarios de stress test, cálculo de límites (capital regulatorio) y mucho más, lo que proporciona\xa0 información detallada y precisa para generar informes y cuadros de mando de riesgos de mercado para alimentar los informes de supervisión bancaria y de gobierno corporativo. Además de\xa0nuestras especializacíon en la detección del fraude y blanqueo de capitales implantando y aprovisionando soluciones de mercado y generando KPIs de seguimiento.\n\n\nTodo ello nos da una perspectiva integral sobre cómo generar valor y analizar riesgos\xa0con el dato de mercado y cómo realizar la gestión de calidad y gobernanza para este tipo\xa0de procesos.\n\n\nRiesgo de mercado\n\n\nRiesgo de contrapartida\n\n\nRiesgos liquidez\n\n\nAnti money laundring\n\n\nMoney Market Statistical Report\n\n\nCodificación de operaciones de clientes.\n\n\nRiesgo Operacional\n\n\nEs la posibilidad de la ocurrencia de pérdidas financieras, causadas por fallos o insuficiencias de procesos, personas, sistemas internos, tecnología, y así como la presencia de eventos externos imprevistos.\n\n\nRiesgo de Mercado\n\n\nSe debe a incertidumbres económicas. La variación en los precios de los activos, pasivos y derivados forma parte de estas fuentes de riesgo: riesgo de cambio, riesgo de tipo de interés, etc.\n\n\nRiesgo de Crédito\n\n\nEs la posibilidad de que una de las partes de un contrato financiero no asuma sus obligaciones. Se trata, pues, de una forma de determinar la capacidad de un deudor para cumplir sus obligaciones de pago.\n\n\nRiesgo de Liquidez\n\n\nEs la posibilidad de que una empresa incumpla sus compromisos de pago debido a que no puede obtener la liquidez necesaria para asumir sus obligaciones a pesar de tener los activos.\n\n\nBlanqueo de Capitales\n\n\nEstamos especializados en la dete ...
# ...
#  Document(id_='561386f1-2173-4787-bed9-38c57d8e79fc', embedding=None, metadata={'file_path': '/Users/gala/PycharmProjects/Scalian_Chat/ScalianChatBot/Data/www_scalian-spain_es_experiencias-de-negocio_railway.txt', 'file_name': 'www_scalian-spain_es_experiencias-de-negocio_railway.txt', 'file_type': 'text/plain', 'file_size': 2749, 'creation_date': '2024-02-06', 'last_modified_date': '2024-02-06', 'last_accessed_date': '2024-02-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nFerroviario\n\n\n0%\n\n\n - Reducción de tiempo y costes del mantenimiento\n - \u200b\n\n - Digitalización y eficiencia en los procesos de\n - mantenimiento preventivo de trenes.\n\nEn colaboración con una de las principales empresas del sector, desarrollamos proyectos que tiene como objetivo final lograr una mayor eficiencia en los procesos de mantenimiento y reparación de los trenes mediante la digitalización de datos y procesos lo que aporta las siguientes ventajas:\n\n\nReducción de tiempo de recolección de datos\n\n\nAumento de la calidad e integridad de los datos (menos errores)\n\n\nMejor disponibilidad de los datos: cualquier momento y lugar\n\n\nGeneración de gráficos y estadísticas para la evaluación de los resultados\n\n\nPermite desarrollar modelos específicos (predictivos, sugerencias)\n\n\nLos modelos obtienen buenos resultados al alimentarse con datos precisos\n\n\nHacia un mantenimiento predictivo de trenes.\n\n\nLa Industria 4.0 está generando gran expectación y muchas empresas se están enfrentando a la realidad de implementar la IA para aprovechar los beneficios del mantenimiento predictivo para ayudar a determinar el estado de los trenes y predecir cuándo debe realizarse el mantenimiento de cada componente.Una vez se dispone de gran cantidad de datos de las averías y de los mantenimientos programados, es posible aplicar algoritmos que ofrezcan un conocimiento inmediato del estado del tren con todas las variables y permitan además el desarrollo de nuevos modelos predictivos.\n\n\nTodas nuestras soluciones  orientadas al futuro de la industria ferrovial.\n\n\nRolling Stock\n\n\n - Desarrollo de sistemas y gestión de proyectos\n - Análisis y definición de requisitos técnicos\n - Diseño e integración\n - Pruebas de diseño\n - Validación y verificación\n - Puesta en marcha y mantenimiento.\n\nDiseño de sistemas de señalización y supervisión\n\n\n - Desarrollo de sistemas y gestión de proyectos\n - Análisis y definición de requisitos\n - Diseño de enclavamientos electrónicos (lógica y vídeo), sistemas ERTMS, y sistemas CBTC\n - Pruebas de diseño\n - Validación y verificación\n - Test & Commisioning.\n\nSoftware tools y automatización de procesos\n\n\nherramientas de software y automatización de procesos para la optimización y mejora de los sistemas ferroviarios.\n\n\nRAMS\n\n\nDepartamento encargado de cumplir la normativa CENELEC en aplicaciones ferroviarias, desarrollando la especificación y asegurando la fiabilidad, disponibilidad, mantenibilidad y seguridad del proyecto.\n\n\nIntegrated logistic support\n\n\nDocumentación de los distintos sistemas en fases de diseño, puesta en marcha, operación y mantenimiento creando informes, manuales y training de formación adaptándose a los distintos idiomas del proyecto.\n\n', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='9d20e257-1c47-4008-8cdd-d73d92ea70cf', embedding=None, metadata={'file_path': '/Users/gala/PycharmProjects/Scalian_Chat/ScalianChatBot/Data/www_scalian-spain_es_experiencias-de-negocio_salud.txt', 'file_name': 'www_scalian-spain_es_experiencias-de-negocio_salud.txt', 'file_type': 'text/plain', 'file_size': 11088, 'creation_date': '2024-02-06', 'last_modified_date': '2024-02-06', 'last_accessed_date': '2024-02-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nSalud\n\n\nAvances tecnológicos que revolucionan el sector y mejoran la vida de las personas a través de los datos.\n\n\n - El uso masivo de los datos y la inteligencia artificial está generando un gran interés y recibiendo una gran inversión como motor de innovación y cambio en multitud de sectores.\n - Todos los estudios apuntan a que habrá un gran cambio en las reglas de juego también en el sector salud con grandes beneficios para la automatización y decisiones basadas en datos.\n\nHacia una medicina P4\n\n\nLa asistencia sanitaria está evolucionando de una atención reactiva a la enfermedad a una atención predictiva, preventiva, personalizada y participativa. Este nuevo enfoque pone el acento en la evolución hacia una medicina basada en información personalizada, obtenida de los datos disponibles no sólo en la historia clínica, sino también de los posibles efectos del genoma, epigenoma, microbioma y salud actual en los tratamientos propuestos.Con seguridad será una medicina que proporcionará una experiencia sanitaria única para cada persona al tratar las causas y no los síntomas y así evitando la incidencia de enfermedades crónicas, que representa cerca del 75% de los costes sanitarios\xa0 en cualquier país desarrollado.\n\n\nMejoramos  la experiencia de usuario:  ayudamos a pacientes y personal médico para superar los retos de usabilidad y garantizar interacciones intuitivas en diferentes aplicaciones y dispositivos, mediante las mejores prácticas de UX/UI.\n\n\nNuestro trabajo en la Salud:\n\n\nMedicina preventiva y predictiva\n\n\nEvolución de pacientes basado en el análisis de grafos.\n\n\nNuestros modelos tratan de evitar los casos de pacientes agudos empeoren en sus sucesivas consultas mediante el uso de inteligencia artificial y perfilado por gravedad y tratamiento.\n\n\nEncontrar hallazgos clínicos en radiografía de tórax\n\n\nScalian Spain en colaboración con uno de los principales proveedores de salud de Europa ha implementado un modelo de Deep Learning que es capaz de identificar en cuestión de segundos hasta 10 patologías en las radiografías de tórax. El modelo tiene una precisión de mas del 80% y permite hacer diagnósticos ultrarrápido de sospecha de neumonía y otras 9 patologías que se pueden detectar comúnmente en las placas de tórax.Estos hallazgos automatizados ayudan a los médicos a interpretar las radiografías con mayor precisión y\xa0 diagnosticar de forma mucho más rápida, lo que permite empezar antes el tratamiento, que es vital para los pacientes gravemente enfermos con enfermedades como la neumonía.\n\n\nRetención de Retinopatías del ojo\n\n\nHemos desarrollado un modelo Deep Learning que es capaz de encontrar las siguientes enfermedades oculares en imagen de ojo: degeneración macular, queratocono, retinopatía diabética\n\n\nServicio de teledermatología basado en la IA\n\n\n - Hemos desarrollado un modelo de\xa0 Deep Learning que permite clasificar lesiones benignas o cánceres de piel malignos alcanzando la precisión equivalente a la de los profesionales en dermatología.\n - Para ello hemos utilizado una técnica de transfer learning con la que preentrenamos una red neuronal profunda de reconocimiento general de objetos y después la validamos con un conjunto de datos de 100.000 imágenes de les ...
#  Document(id_='5e024c37-a6e8-4763-a646-afc70582072d', embedding=None, metadata={'file_path': '/Users/gala/PycharmProjects/Scalian_Chat/ScalianChatBot/Data/www_scalian-spain_es_experiencias-de-negocio_telco.txt', 'file_name': 'www_scalian-spain_es_experiencias-de-negocio_telco.txt', 'file_type': 'text/plain', 'file_size': 4791, 'creation_date': '2024-02-06', 'last_modified_date': '2024-02-06', 'last_accessed_date': '2024-02-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nTelecomunicaciones\n\n\nEn uno de los sectores con mayor nivel de competencia, la gestión y puesta en valor de los datos y la eficiencia en las operaciones es clave para mejorar la rentabilidad, la capacidad de captación y retención de clientes, y la sostenibilidad de las empresas.\n\n\nSomos el equipo de expertos que necesitas.\n\n\nExperiencia + Conocimiento del Negocio + Nuevas Tecnologías + Metodología\n\n\nExperiencia\n\n\nScalian Spain ha ayudado durante más de 10 años a las principales compañías del sector Telco.\n\n\nConocimiento del Negocio\n\n\nNuestro conocimiento abarca la mayor parte de los ámbitos del negocio (redes, gestión de clientes, definición de portfolios, IT, etc.), por lo que disponemos de un gran conocimiento del sector.\n\n\nNuevas Tecnologías\n\n\nSomos especialistas en tecnologías como Inteligencia Artificial, plataformas de datos escalables, cloud, etc.\n\n\nMetodologías\n\n\nPonemos en valor nuestra capacidad de gestión y optimización de operaciones complejas, así como un gran conocimiento en metodologías y frameworks que mejoran la eficiencia de los procesos.\n\n\nTransformando los datos para atender mejor\n\n\nEn este sector una vez más la importancia de la transformación digital está teniendo un gran peso en la demanda de los usuarios por lo que todas las empresas del sector se ven obligadas a incorporar un cambio y una innovación en términos de procesos tecnológicos de la mano de la Inteligencia Artificial y los datos.\n\n\nNos sumamos a la Transformación Digital en el sector de las Telecomunicaciones para agilizar el negocio y ofrecer mejores servicios al consumidor.\n\n\nMigración de plataformas a cloud\n\n\nLa necesidad de adaptar las capacidades de IT a la demanda, la reducción del time-to-market, la sustitución de CAPEX por OPEX o el nivel de madurez de las plataformas cloud está motivando la migración de arquitecturas IT a la nube o a sistemas híbridos.Scalian ha ayudado a clientes de Telco en sus planes de migración de plataformas así como en los proyectos de integración, ofreciendo soluciones que reducen el time-to-market y el vendor lock-in, así como los costes asociados a este tipo de iniciativas.\n\n\nSistemas de tiempo real\n\n\nEl sector telco es uno de los que tradicionalmente más ha lidiado con la gestión de datos y eventos en tiempo real, para lo que se han utilizado plataformas específicas que permiten resolver casos de uso de forma específica.Scalian se ha especializado en la construcción de sistemas de tiempo real de propósito general que permiten dar respuesta, desde una única plataforma, a diferentes casos de uso como el geoposicionamiento de clientes, la generación de alertas, o la medición de variables clave con volumetrías elevadas y tiempos de respuesta de milisegundos.\n\n\nDemocratización de datos\n\n\nHabilitar los datos de los diferentes dominios, que tradicionalmente han sido gestionados en sistemas aislados, para su explotación por diferentes áreas, ha sido uno de los desafíos más importantes a los que las compañías de Telco se han enfrentado en los últimos años en materia de tecnología.Scalian Spain ha ayudado desde hace más de 8 años a las compañías del sector a la implementación de lagos de datos y su evolución hacia concepciones más eficientes y escalab ...
#  Document(id_='c613de4b-7c39-4634-a8bc-2ac144a821b8', embedding=None, metadata={'file_path': '/Users/gala/PycharmProjects/Scalian_Chat/ScalianChatBot/Data/www_scalian-spain_es_talento-talante.txt', 'file_name': 'www_scalian-spain_es_talento-talante.txt', 'file_type': 'text/plain', 'file_size': 7118, 'creation_date': '2024-02-06', 'last_modified_date': '2024-02-06', 'last_accessed_date': '2024-02-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nTalento Creativo y Talante Innovador\n\n\nLos objetivos conseguidos los define nuestro talento, nuestro talante queda determinado por cómo los hemos alcanzado.\n\n\nEspíritu  Scalian Spain\n\n\nEn nuestro\xa0equipo\xa0sentimos\xa0pasión y curiosidad \u202fpor lo que hacemos,\xa0además\xa0de la\xa0satisfacción\xa0de que nuestro\xa0trabajo contribuye a mejorar la vida de las personas, cada día aportamos\xa0un poco más a hacer de éste un mundo mejor.\xa0\xa0Tanto nuestras\xa0capacidades técnicas como nuestra habilidades sociales y\xa0aptitudes\xa0nos definen como\xa0Scalians, y nos ayudan a aprender cosas\xa0nuevas cada día y a desarrollar y desplegar nuestro conocimiento en\xa0actividades tanto técnicas como de gestión.\n\n\n¡Sé Auténtico!\n\n\nLa autenticidad de un SCALIAN se expresa con su disposición o manera de ser y hacer las cosas y tiene mucho que\xa0ver con cómo afronta los retos del día a día.En SCALIAN\xa0respetamos ese carácter autentico de cada persona y consideramos que preservar las señas de identidad de cada uno es importante\xa0 para conseguir la motivación y la integración de todos los miembros de este gran equipo.\n\n\n¡Sé Curioso!\n\n\nSé innovador y curioso,\xa0profundiza en el estudio sobre tecnologías y sobre el contexto del negocio en el que estés involucrado. Investigar, probar nuevas cosas y compartir conocimiento\xa0es parte de nuestro\xa0trabajo.\n\n\n¡Sé Apasionado!\n\n\nIntenta enfrentar los desafíos con ilusión y determinación,\xa0verás que así las cosas siempre salen y es una grata recompensa\xa0que siempre acompaña\xa0al trabajo bien hecho.\n\n\nEstos son los Principios para Ser un Verdadero SCALIAN\n\n\nGroucho Marx decía “Éstos son mis principios, y si no le gustan, tengo otros”\xa0Para los\xa0SCALIANS\xa0los principios y valores son algo casi sagrado y no podríamos tener otros, es algo fundamental desde donde nos\xa0definimos como empresa y desde donde emanan las virtudes, pero también algunos defectos que guían nuestras decisiones y\xa0acciones.Estos son nuestros valores desde la perspectiva del empleado, cliente,\xa0partners\xa0y sociedad.\n\n\nConfianzaInnovaciónAutenticidadCompromiso\n\n\nHonestidad, Reconocimiento y Cercanía\xa0Empleado: Poner interés y esmero por lo que hacemos cada día y ser ágiles y eficaces en conseguir aquello que nos proponemos/comprometemos.\xa0Cliente: Actuar siempre atendiendo a valores éticos de honestidad y franqueza que nos hagan merecedores de la confianza y respeto de la gente con la que trabajamos.\xa0Partner: Establecer alianzas sólidas, justas, de igual a igual y duraderas con otras empresas o instituciones.\xa0Sociedad:\u202f Trabajar por el bienestar las personas que queremos sabiendo que su felicidad dependerá de nuestros actos para hacer una sociedad mejor y mas justa.\xa0Excelencia, Inquietud, Talento, AprendizajeEmpleado: Ser novedosos y punteros en todas nuestras facetas y practicar el “ser curioso” para aprender y reciclarnos.\u200bCliente: Aportar soluciones tecnológicas creativas y prácticas que generen impacto positivo en la actividad de nuestros\xa0clientes/sociedad.\u200bPartner: Expandir nuestras posibilidades de negocio y de crecimiento mediante la innovación abierta con nuestros socios.\u200bSociedad: Facilitar la vida de las personas a través de la transformac ...

# %% [markdown]
# As expected, in the list, we have one document with the type llama_index.schema.Document. Now let's try to index our document in the vector database. This is handled by the class
# ## **ChatGPTRetrievalPluginIndex**. It has a method for creating an index based on a list of documents called `from_documents`. There are various vector databases available for this purpose.

# %% [markdown]
# GPTSimpleVectorIndex
#
# GPTFaissIndex
#
# GPTWeaviateIndex
#
# GPTPineconeIndex
#
# GPTQdrantIndex
#
# GPTChromaIndex
#
# GPTMilvusIndex
#
# GPTDeepLakeIndex
#
# GPTMyScaleIndex

# %% [markdown]
# ## GPTSimpleVectorIndex

# %%
from llama_index.indices.vector_store import GPTVectorStoreIndex
from llama_index.indices.keyword_table import GPTKeywordTableIndex

# %% [markdown]
# For now, we are using the simple option GPTSimpleVectorIndex, but beforehand, you need to set the OpenAI API key to use the embedding model.

# %% [markdown]
# In llamaIndex, the query_engine is an object that manages the search process in the index. The index is a data structure that stores "nodes." A node corresponds to a fragment of text from a document. LlamaIndex takes document objects and internally breaks them into node objects.
#
# In our case, it searches only through one node because we haven't split our text into nodes.
# .

# %%
# index object
index = GPTVectorStoreIndex.from_documents(documents)


# query engine object
query_engine = index.as_query_engine()

# query to the index
response2 = query_engine.query(
	'What strategies does Scalian Spain employ to ensure a smooth transition to new operational management paradigms, and how do they integrate digitalization, performance management, and expertise to achieve this goal?'
)
print(response2.response)
# Out:
# Scalian Spain employs a combination of digitalization of processes, digital transformation, and performance management expertise to ensure a smooth transition to new operational management paradigms. They integrate these strategies by leveraging the latest technologies and the support of their Data & Insights division. This includes optimizing processes, improving operational intelligence, forecasting and planning, establishing production policies and programs, and developing data collection systems and digital processes. By visualizing and analyzing real-time data in their supply chain and production, Scalian Spain aims to enhance response capability, performance, quality, cost, and efficiency. Additionally, they focus on improving asset reliability and availability while minimizing operational risks and costs. Overall, Scalian Spain's approach involves a holistic integration of digitalization, performance management, and expertise to drive business growth and enhance operational performance.

# %%
# level of confidence
response2.source_nodes[0].score
# Out:
# 0.8539750999601693

# %%
response2
# Out:
# Response(response="Scalian Spain employs a combination of digitalization of processes, digital transformation, and performance management expertise to ensure a smooth transition to new operational management paradigms. They integrate these strategies by leveraging the latest technologies and the support of their Data & Insights division. This includes optimizing processes, improving operational intelligence, forecasting and planning, establishing production policies and programs, and developing data collection systems and digital processes. By visualizing and analyzing real-time data in their supply chain and production, Scalian Spain aims to enhance response capability, performance, quality, cost, and efficiency. Additionally, they focus on improving asset reliability and availability while minimizing operational risks and costs. Overall, Scalian Spain's approach involves a holistic integration of digitalization, performance management, and expertise to drive business growth and enhance operational performance.", source_nodes=[NodeWithScore(node=TextNode(id_='d51a35bf-48b2-4dcf-8066-83fb099e1b67', embedding=None, metadata={'file_path': '/Users/gala/PycharmProjects/Scalian_Chat/ScalianChatBot/Data/www_scalian-spain_es_especializacion_operations-performance.txt', 'file_name': 'www_scalian-spain_es_especializacion_operations-performance.txt', 'file_type': 'text/plain', 'file_size': 4125, 'creation_date': '2024-02-06', 'last_modified_date': '2024-02-06', 'last_accessed_date': '2024-02-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='33d0898b-9969-4108-a88b-d165be8e143a', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': '/Users/gala/PycharmProjects/Scalian_Chat/ScalianChatBot/Data/www_scalian-spain_es_especializacion_operations-performance.txt', 'file_name': 'www_scalian-spain_es_especializacion_operations-performance.txt', 'file_type': 'text/plain', 'file_size': 4125, 'creation_date': '2024-02-06', 'last_modified_date': '2024-02-06', 'last_accessed_date': '2024-02-06'}, hash='0d5048de5e09eb42c528f15c6fb077ae6af955bdd71393378bcbb07a70718c31'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='d6cd1ac6-42f3-4bd2-ac1e-c473ce36528f', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': '/Users/gala/PycharmProjects/Scalian_Chat/ScalianChatBot/Data/www_scalian-spain_es_especializacion_digital-solutions.txt', 'file_name': 'www_scalian-spain_es_especializacion_digital-solutions.txt', 'file_type': 'text/plain', 'file_size': 5034, 'creation_date': '2024-02-06', 'last_modified_date': '2024-02-06', 'last_accessed_date': '2024-02-06'}, hash='acd76c2116675d69d38de3c52dc7dd9b16f36f32aa6b345013eb3c38a1f3a629'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='95b03614-b7f7-4c98-9572-8bb250a7d8c5', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='c67898309d7ab24157ed2b17b5a3f417dae11578d545ce4982325a130cd54206')}, text='Operations Performance\n\n\nCombinamos la capacidad de digitalización de procesos y transformación digital junto con nuestra aptitud de gestión del rendimiento de las operaciones para asegurar una transición segura a nuevos paradigmas de gestión de las operaciones.\n\n\nImpulsando el negocio.\n\n\nEn Scalian Spain somos expertos en ayudar a las empresas a establecer sinergias entre sus distintas unidades productivas y departamentos dotándolos de las herramienta y los servicios que que les permitan incrementar de forma considerable su rendimiento y su capacidad operativa para producir conjuntamente de forma que se consigan los objetivos empresariales que se propongan al tiempo que se mejora la capacidad de respuesta, el rendimiento, la calidad, el coste y la eficiencia de sus sistemas de producción o servicios.\n\ ...

# %% [markdown]
# It is important to note that "relevance" here is determined by the model trained to understand which nodes may be relevant to a specific query. This may involve analyzing the semantic content of the query and nodes, as well as other factors.
